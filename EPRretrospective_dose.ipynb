# %% [markdown]
# <a href="https://colab.research.google.com/github/majavk/EPRbiodose/blob/main/EPRretrospective_dose.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import arange
import os
import pandas as pd
from scipy.optimize import curve_fit
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/EPR/EPR_posao/EPR/08052017/FT_3 orijentacije_ N 20'
file_type = '.csv'

filenames = list()
for filename in os.listdir(path=path):
    if filename.endswith(file_type):
        filenames.append(filename)

# %%
#one file in a folder is empty
MIN_ROW = 85
pd.read_csv(f'{path}/' + 'FT_No1_300_20052022_002.csv', header=None).iloc[MIN_ROW:, :]

# %% [markdown]
# Storing the spectral data in the data frame. The files acquired from the measurements are having 1st 85 rows filled with measurement condtitions.

# %%
df_final = pd.DataFrame()

MIN_ROW = 85
for i, item in enumerate(filenames):
    variable_filename = '_' + item
    variable_name_to_change = item
    variable_name_to_change = pd.read_csv(f'{path}/' + item, header=None).iloc[MIN_ROW:, :]
    field_variable_name_to_change = list()
    ampl_variable_name_to_change = list()

    for  row in variable_name_to_change.itertuples():
      field_variable_name_to_change.append(float(row[1].split(';')[0]))
      ampl_variable_name_to_change.append(float(row[1].split(';')[1]))
      
    row_field_variable ='new_field' + str(variable_filename)
    row_ampl_variable = 'new_ampl' + str(variable_filename)
    try:
      df_final[row_field_variable] = field_variable_name_to_change
      df_final[row_ampl_variable] = ampl_variable_name_to_change
    except ValueError:
      print(f'{i}th row is having a Value Error')

df_final.head()
# Out:
# 7th row is having a Value Error
#    new_field_FT_No10_180_10062022_result.csv  \
# 0                                 326.000000
# 1                                 326.000333
# 2                                 326.000667
# 3                                 326.001000
# 4                                 326.001333
#
#    new_ampl_FT_No10_180_10062022_result.csv  \
# 0                                 25.893702
# 1                                 25.901341
# 2                                 25.908980
# 3                                 25.915817
# 4                                 25.922493
#
#    new_field_FT_No1_60_20052022_result.csv  \
# 0                               326.000000
# 1                               326.000333
# 2                               326.000667
# 3                               326.001000
# 4                               326.001333
#
#    new_ampl_FT_No1_60_20052022_result.csv  \
# 0                               30.459298
# 1                               30.462603
# 2                               30.465907
# 3                               30.469211
# 4                               30.472516
#
#    new_field_FT_No10_60_10062022_result.csv  \
# 0                                326.000000
# 1                                326.000333
# 2                                326.000667
# 3                                326.001000
# 4                                326.001333
#
#    new_ampl_FT_No10_60_10062022_result.csv  \
# 0                                21.858613
# 1                                21.856854
# 2                                21.855095
# 3                                21.853337
# 4                                21.851613
#
#    new_field_FT_No11_180_10062022_result.csv  \
# 0                                 326.000000
# 1                                 326.000333
# 2                                 326.000667
# 3                                 326.001000
# 4                                 326.001333
#
#    new_ampl_FT_No11_180_10062022_result.csv  \
# 0                                 27.856200
# 1                                 27.858653
# 2                                 27.861106
# 3                                 27.863559
# 4                                 27.866011
#
#    new_field_FT_No10_300_10062022_result.csv  \
# 0                                 326.000000
# 1                                 326.000333
# 2                                 326.000667
# 3                                 326.001000
# 4                                 326.001333
#
#    new_ampl_FT_No10_300_10062022_result.csv  ...  \
# 0                                 26.477697  ...
# 1                                 26.482638  ...
# 2                                 26.487579  ...
# 3                                 26.492519  ...
# 4                                 26.497575  ...
#
#    new_field_FT_No8_180_19052022_result.csv  \
# 0                                326.000000
# 1                                326.000333
# 2                                326.000667
# 3                                326.001000
# 4                                326.001333
#
#    new_ampl_FT_No8_180_19052022_result.csv  \
# 0                                35.825387
# 1                                35.819369
# 2                                35.812618
# 3                                35.805866
# 4                                35.799114
#
#    new_field_FT_No9_60_19052022_result.csv  \
# 0                               326.000000
# 1                               326.000333
# 2                               326.000667
# 3                               326.001000
# 4                               326.001333
#
#    new_ampl_FT_No9_60_19052022_result.csv  \
# 0                               22.474807
# 1                               22.474819
# 2                               22.474830
# 3                               22.482296
# 4                               22.489816
#
#    new_field_FT_No9_180_19052022_result.csv  \
# 0                                326.000000
# 1                                326.000333
# 2                                326.000667
# 3                                326.001000
# 4                                326.001333
#
#    new_ampl_FT_No9_180_19052022_result.csv  \
# 0                                30.249027
# 1                                30.244624
# 2                                30.240221
# 3                                30.235843
# 4                                30.231733
#
#    new_field_FT_No8_300_19052022_result.csv  \
# 0                                326.000000
# 1                                326.000333
# 2                                326.000667
# 3                                326.001000
# 4                                326.001333
#
#    new_ampl_FT_No8_300_19052022_result.csv  \
# 0                                31.966345
# 1                                31.969268
# 2                                31.972190
# 3                                31.975112
# 4                                31.978034
#
#    new_field_FT_No8_60_19052022_result.csv  \
# 0                               326.000000
# 1                               326.000333
# 2                               326.000667
# 3                               326.001000
# 4                               326.001333
#
#    new_ampl_FT_No8_60_19052022_result.csv
# 0                               34.264772
# 1                               34.260534
# 2                               34.256297
# 3                               34.252060
# 4                               34.247823
#
# [5 rows x 118 columns]

# %% [markdown]
# The data of a spectra are separated in the first part where the standard, left, 3rd satelite of Mn2+ in MgO lies, for the field calibration data are and the second part where the data for the maximum of the EPR spectra of the sample response is.

# %%
df_Mn_left = df_final[(df_final.iloc[:,0]> 330.) & (df_final.iloc[:, 0] < 333.)]
df_geff = df_final[(df_final.iloc[:,0]> 333.5) & (df_final.iloc[:, 0] < 338.)]

# %%
print(df_Mn_left.shape)
print(df_geff.shape)
# Out:
# (9000, 118)
# (13500, 118)

# %% [markdown]
# Separating field and amplitude spectral data for standard and sample signal.

# %%
data = df_Mn_left.to_dict()
mn_left = pd.DataFrame()

for key, value in data.items():
    if 'ampl' in key:)
        B_MN_left_variable = 'B_Mn_left_'+key
        B_MN_left_column_variable = 'B_Mn_left_column_'+key
        values_Mn = 'values_Mn_'+ key
        values_Mn = list()
        for x,y in value.items():
            values_Mn.append(y)
        mn_left[B_MN_left_column_variable] = values_Mn
        
mn_left.head()
# Out:
#    B_Mn_left_column_new_ampl_FT_No10_180_10062022_result.csv  \
# 0                                          -2.179855
# 1                                          -2.173771
# 2                                          -2.167686
# 3                                          -2.161602
# 4                                          -2.155515
#
#    B_Mn_left_column_new_ampl_FT_No1_60_20052022_result.csv  \
# 0                                          -3.203578
# 1                                          -3.195031
# 2                                          -3.186189
# 3                                          -3.177347
# 4                                          -3.168505
#
#    B_Mn_left_column_new_ampl_FT_No10_60_10062022_result.csv  \
# 0                                          -5.862995
# 1                                          -5.864078
# 2                                          -5.865162
# 3                                          -5.866244
# 4                                          -5.867327
#
#    B_Mn_left_column_new_ampl_FT_No11_180_10062022_result.csv  \
# 0                                          -3.833249
# 1                                          -3.838153
# 2                                          -3.843085
# 3                                          -3.848030
# 4                                          -3.852976
#
#    B_Mn_left_column_new_ampl_FT_No10_300_10062022_result.csv  \
# 0                                          -1.939709
# 1                                          -1.938673
# 2                                          -1.937636
# 3                                          -1.936599
# 4                                          -1.935562
#
#    B_Mn_left_column_new_ampl_FT_No1_180_20052022_result.csv  \
# 0                                          -1.550532
# 1                                          -1.547056
# 2                                          -1.543579
# 3                                          -1.540100
# 4                                          -1.536624
#
#    B_Mn_left_column_new_ampl_FT_No11_300_10062022_result.csv  \
# 0                                          -4.843958
# 1                                          -4.842253
# 2                                          -4.840548
# 3                                          -4.838844
# 4                                          -4.836977
#
#    B_Mn_left_column_new_ampl_FT_No12_300_10062022_result.csv  \
# 0                                          -1.321955
# 1                                          -1.315104
# 2                                          -1.308253
# 3                                          -1.301402
# 4                                          -1.294552
#
#    B_Mn_left_column_new_ampl_FT_No12_60_10062022_result.csv  \
# 0                                          -8.268413
# 1                                          -8.266062
# 2                                          -8.263710
# 3                                          -8.261359
# 4                                          -8.259008
#
#    B_Mn_left_column_new_ampl_FT_No13_300_10062022_result.csv  ...  \
# 0                                          -6.563918          ...
# 1                                          -6.565546          ...
# 2                                          -6.567175          ...
# 3                                          -6.568804          ...
# 4                                          -6.570433          ...
#
#    B_Mn_left_column_new_ampl_FT_No5_300_20052022_result.csv  \
# 0                                          -1.491152
# 1                                          -1.483161
# 2                                          -1.475156
# 3                                          -1.466666
# 4                                          -1.458177
#
#    B_Mn_left_column_new_ampl_FT_No6_300_20052022_result.csv  \
# 0                                          -0.961118
# 1                                          -0.964622
# 2                                          -0.968706
# 3                                          -0.972790
# 4                                          -0.976873
#
#    B_Mn_left_column_new_ampl_FT_No7_300_19052022_result.csv  \
# 0                                          -4.601973
# 1                                          -4.601874
# 2                                          -4.602230
# 3                                          -4.602639
# 4                                          -4.603048
#
#    B_Mn_left_column_new_ampl_FT_No7_60_19052022_result.csv  \
# 0                                          -6.139305
# 1                                          -6.143562
# 2                                          -6.147820
# 3                                          -6.152078
# 4                                          -6.156337
#
#    B_Mn_left_column_new_ampl_FT_No9_300_19052022_result.csv  \
# 0                                           1.016316
# 1                                           1.018493
# 2                                           1.020670
# 3                                           1.022847
# 4                                           1.025024
#
#    B_Mn_left_column_new_ampl_FT_No8_180_19052022_result.csv  \
# 0                                           2.590200
# 1                                           2.584763
# 2                                           2.579332
# 3                                           2.572806
# 4                                           2.566073
#
#    B_Mn_left_column_new_ampl_FT_No9_60_19052022_result.csv  \
# 0                                          -6.453105
# 1                                          -6.446823
# 2                                          -6.440539
# 3                                          -6.434254
# 4                                          -6.427970
#
#    B_Mn_left_column_new_ampl_FT_No9_180_19052022_result.csv  \
# 0                                          -4.885062
# 1                                          -4.883024
# 2                                          -4.879631
# 3                                          -4.876089
# 4                                          -4.872547
#
#    B_Mn_left_column_new_ampl_FT_No8_300_19052022_result.csv  \
# 0                                          -3.352084
# 1                                          -3.350208
# 2                                          -3.348333
# 3                                          -3.346458
# 4                                          -3.344584
#
#    B_Mn_left_column_new_ampl_FT_No8_60_19052022_result.csv
# 0                                           1.576985
# 1                                           1.571826
# 2                                           1.566671
# 3                                           1.561517
# 4                                           1.556362
#
# [5 rows x 59 columns]

# %%
data_1 = df_geff.to_dict()
df_geffective = pd.DataFrame()

for key, value in data_1.items():
    if 'ampl'in key:
        B_g_eff_variable = 'B_g_eff_'+key
        B_g_eff_column_variable = 'B_g_eff_column_'+key
        values = 'values_'+ key
        values = list()
        for x,y in value.items():
            values.append(y)
        df_geffective[B_g_eff_column_variable] = values
df_geffective.head()
# Out:
#    B_g_eff_column_new_ampl_FT_No10_180_10062022_result.csv  \
# 0                                          31.395774
# 1                                          31.403345
# 2                                          31.410916
# 3                                          31.418488
# 4                                          31.426058
#
#    B_g_eff_column_new_ampl_FT_No1_60_20052022_result.csv  \
# 0                                          29.281642
# 1                                          29.301625
# 2                                          29.321608
# 3                                          29.341591
# 4                                          29.361566
#
#    B_g_eff_column_new_ampl_FT_No10_60_10062022_result.csv  \
# 0                                          27.444855
# 1                                          27.458808
# 2                                          27.472754
# 3                                          27.486709
# 4                                          27.500658
#
#    B_g_eff_column_new_ampl_FT_No11_180_10062022_result.csv  \
# 0                                          30.948386
# 1                                          30.952816
# 2                                          30.957244
# 3                                          30.961674
# 4                                          30.966103
#
#    B_g_eff_column_new_ampl_FT_No10_300_10062022_result.csv  \
# 0                                          28.179696
# 1                                          28.189512
# 2                                          28.199339
# 3                                          28.209157
# 4                                          28.218976
#
#    B_g_eff_column_new_ampl_FT_No1_180_20052022_result.csv  \
# 0                                          30.897371
# 1                                          30.900385
# 2                                          30.903402
# 3                                          30.906414
# 4                                          30.909430
#
#    B_g_eff_column_new_ampl_FT_No11_300_10062022_result.csv  \
# 0                                          26.187235
# 1                                          26.192132
# 2                                          26.197028
# 3                                          26.201925
# 4                                          26.206822
#
#    B_g_eff_column_new_ampl_FT_No12_300_10062022_result.csv  \
# 0                                          29.414765
# 1                                          29.428304
# 2                                          29.441848
# 3                                          29.455393
# 4                                          29.468938
#
#    B_g_eff_column_new_ampl_FT_No12_60_10062022_result.csv  \
# 0                                          25.066687
# 1                                          25.070243
# 2                                          25.075180
# 3                                          25.081700
# 4                                          25.088221
#
#    B_g_eff_column_new_ampl_FT_No13_300_10062022_result.csv  ...  \
# 0                                          26.276240        ...
# 1                                          26.280198        ...
# 2                                          26.284156        ...
# 3                                          26.288114        ...
# 4                                          26.292072        ...
#
#    B_g_eff_column_new_ampl_FT_No5_300_20052022_result.csv  \
# 0                                          32.241039
# 1                                          32.248453
# 2                                          32.255806
# 3                                          32.263159
# 4                                          32.270512
#
#    B_g_eff_column_new_ampl_FT_No6_300_20052022_result.csv  \
# 0                                          26.185235
# 1                                          26.184100
# 2                                          26.183573
# 3                                          26.183284
# 4                                          26.182995
#
#    B_g_eff_column_new_ampl_FT_No7_300_19052022_result.csv  \
# 0                                          28.088501
# 1                                          28.101236
# 2                                          28.113729
# 3                                          28.126226
# 4                                          28.138722
#
#    B_g_eff_column_new_ampl_FT_No7_60_19052022_result.csv  \
# 0                                          24.665810
# 1                                          24.675256
# 2                                          24.684714
# 3                                          24.694163
# 4                                          24.703611
#
#    B_g_eff_column_new_ampl_FT_No9_300_19052022_result.csv  \
# 0                                          28.148197
# 1                                          28.156527
# 2                                          28.164849
# 3                                          28.173171
# 4                                          28.181493
#
#    B_g_eff_column_new_ampl_FT_No8_180_19052022_result.csv  \
# 0                                          28.147599
# 1                                          28.148100
# 2                                          28.148600
# 3                                          28.149848
# 4                                          28.151177
#
#    B_g_eff_column_new_ampl_FT_No9_60_19052022_result.csv  \
# 0                                          25.807787
# 1                                          25.818632
# 2                                          25.829476
# 3                                          25.840328
# 4                                          25.851170
#
#    B_g_eff_column_new_ampl_FT_No9_180_19052022_result.csv  \
# 0                                          27.360306
# 1                                          27.354844
# 2                                          27.349547
# 3                                          27.344249
# 4                                          27.338950
#
#    B_g_eff_column_new_ampl_FT_No8_300_19052022_result.csv  \
# 0                                          27.419904
# 1                                          27.427088
# 2                                          27.434275
# 3                                          27.441459
# 4                                          27.448645
#
#    B_g_eff_column_new_ampl_FT_No8_60_19052022_result.csv
# 0                                          31.319350
# 1                                          31.323371
# 2                                          31.327393
# 3                                          31.331414
# 4                                          31.335435
#
# [5 rows x 59 columns]

# %% [markdown]
# Evaluation of the g-values from the EPR spectral response (position of magnetic field where the absorption happened).

# %%
def g_values(B_Mn_left, B_g_eff):
    g_Mn_left = 2.03339
    g_eff = g_Mn_left * (B_Mn_left/B_g_eff)
    return g_eff

# %% [markdown]
# Evaluation of magnetic field of maximum of EPR spectra for sample and the standard.

# %%
max_names = list()
max_values = list()
max_index = list()
for item in mn_left.columns.values.tolist():
    max_value = mn_left[item].sort_values(ascending=False)[:1]
    max_names.append(max_value.name)
    max_values.append(max_value.values[0])
    max_index.append(list(max_value.index)[0])
    
zipped_Mn = zip(max_names, max_values, max_index)
ampl_data_Mn = list(zipped_Mn)

# %%
max_names_geff = list()
max_values_geff = list()
max_index_geff = list()

for item in df_geffective.columns.values.tolist():
    max_value = df_geffective[item].sort_values(ascending=False)[:1]
    max_names_geff.append(max_value.name)
    max_values_geff.append(max_value.values[0])
    max_index_geff.append(list(max_value.index)[0])
    
zipped_g_eff = zip(max_names_geff, max_values_geff, max_index_geff)
ampl_data_g_eff = list(zipped_g_eff)

# %%
zipped_g_eff_Mn = zip(max_names, max_values, max_index, max_names_geff, max_values_geff, max_index_geff)
zipped_g_eff_Mn = list(zipped_g_eff_Mn)

# %% [markdown]
# Evaluation of the g_eff values and storing in the data frame.

# %%
df = pd.DataFrame()

g_eff = list()
dose = list()
b_g_eff = list()
b_Mn_left = list()
for  name, value, index, name_geff, value_geff, index_geff in zipped_g_eff_Mn:
    replaced_name_geff = name_geff[15:].replace('ampl', 'field')
    replaced_name = name[17:].replace('ampl', 'field')
    B_g_eff = df_geff[replaced_name_geff].iloc[index_geff]
    B_Mn_left = df_Mn_left[replaced_name].iloc[index]
    variable_name = 'g_eff_' + replaced_name
    dose.append(variable_name)
    g_eff.append(g_values(B_Mn_left, B_g_eff))
    b_g_eff.append(B_g_eff)
    b_Mn_left.append(B_Mn_left)

df['g_eff'] = g_eff
df['meta_data'] = dose
df['B_g_eff'] = b_g_eff
df['B_Mn_left'] = b_Mn_left

# %% [markdown]
# Extracting the information on the dose, orientation and the sample from the column names.

# %%
orientation = list()
sample = list()
for item in df['meta_data']:
  item = item.split('No')
  item = item[1][0:6]
  try:
    if item.endswith('_'):
      orientation.append(float(item[0:5].split('_')[1]))
      sample.append(float(item[0:5].split('_')[0]))
    else:
      orientation.append(float(item.split('_')[1]))
      sample.append(float(item.split('_')[0]))
  except IndexError:
    continue

df['No_sample'] = sample
df['orientation_sample'] = orientation
df_temp = df[['No_sample', 'orientation_sample', 'g_eff']]
df_temp = df_temp.sort_values('No_sample') 
df_temp

# %%
df_temp = df_temp.groupby('No_sample').mean()

# %% [markdown]
# By using previously established calibration curve, the dose evaluation from the g_eff values was performed.

# %%
def reverse_cal(g_eff, y_0, a, b):
  return -1/b * np.log((a-g_eff+y_0)/a)

# %%
df_temp['dose'] = df_temp['g_eff'].apply(lambda x: reverse_cal(x, 2.0082, 0.0032, 0.524))
df = df_temp[['g_eff', 'dose']]
